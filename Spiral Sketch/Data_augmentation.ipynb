# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd

# %%
import tensorflow as tf
from tensorflow import keras
print("Number of GPUS : ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
print(tf. test. gpu_device_name)
# Out:
# Number of GPUS :  1
# <function gpu_device_name at 0x000001C12689D700>

# %%
data_train = np.load('Parkinson_disease_detection/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %% [markdown]
# ***Augmenting Train Dataset***

# %%
train_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True, 
                                    vertical_flip=True)

# %%
x = list(x_train)
y = list(y_train)

# %%
len(x)
len(y)
# Out:
# 72

# %%
x_aug_train = []
y_aug_train = []

# %%
for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)

# %%
print(len(x_aug_train))
print(len(y_aug_train))
# Out:
# 5040
# 5040

# %%
x_train = x + x_aug_train
y_train = y + y_aug_train

# %%
print(len(x_train))
print(len(y_train))
# Out:
# 5112
# 5112

# %%
type(x_train[0])
# Out:
# numpy.ndarray

# %% [markdown]
# ***Augmenting Test Dataset***

# %%
test_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True, 
                                    vertical_flip=True)

# %%
xt = list(x_test)
yt = list(y_test)

# %%
x_aug_test = []
y_aug_test = []

# %%
len(xt)
# len(x_aug_test)
# Out:
# 30

# %%
for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)

# %%
print(len(x_aug_test))
print(len(y_aug_test))

x_test = xt + x_aug_test
y_test = yt + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 1440
# 1440
# 1470
# 1470

# %%
# data_test = np.load('Parkinson_disease_detection/test_set.npz', allow_pickle=True)
# x_test = data_test['arr_0']
# y_test = data_test['arr_1']

# print(x_test.shape)
# print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %%
type(x_aug_train[0])
# Out:
# numpy.ndarray

# %%
import os.path
from PIL import Image

healthy_path = "dataset/train/healthy"
parkinson_path = "dataset/train/parkinson"

# %%
# for aug_train in range(0,len(x_train)+1):
#     img=Image.fromarray(x_train[aug_train])
#     y_name = y_train[aug_train]
#     if y_name == "healthy" :
        
#     img.save(y_name + str(aug_train) + ".jpeg")

for aug_train in range(0, len(x_test)):
    img = Image.fromarray(x_test[aug_train])
    y_name = y_test[aug_train]
    img.save(y_name + str(aug_train) + ".jpeg")

# %%
import os.path
from PIL import Image

healthy_path_test = "dataset/test/healthy"
parkinson_path_test = "dataset/test/parkinson"

for aug_test in range(0, len(x_test)):
    img = Image.fromarray(x_test[aug_test])
    y_name = y_test[aug_test]
    img.save(y_name + str(aug_test) + ".jpeg")

# %%
type(y_aug_train[0])
y_aug_train[0]
from PIL import Image
for aug_train in range(0,len(x_train)+1):
    img=Image.fromarray(x_train[aug_train])
    y_name = y_train[aug_train]
    print(y_name)
    img.save(y_name + str(aug_train) + ".jpeg")
#     cv2.imwrite(os.path.join('' + str(i) + '.bmp'), newImage)
    
# im = Image.fromarray(x_aug_train[0])
# im.save("your_file.jpeg")
# Out:
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# parkinson
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# ...
